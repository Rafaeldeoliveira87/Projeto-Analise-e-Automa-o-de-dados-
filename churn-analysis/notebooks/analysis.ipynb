# %%
import pandas as pd

# %%
df= pd.read_csv('../data/Churn_Modelling.csv')

display(df.head())
display(df.info())
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %% [markdown]
# Objetivo:
#
# Responder:
# Quantos clientes cancelaram?

# %%
df['Status'] = df['Exited'].replace({0: 'Ficou', 1: 'Saiu'})
display(df['Exited'].value_counts())

display(df['Exited'].value_counts(normalize=True) * 100)
# Out:
# Exited
# 0    7963
# 1    2037
# Name: count, dtype: int64
# Exited
# 0    79.63
# 1    20.37
# Name: proportion, dtype: float64

# %% [markdown]
# - Quem cancela mais?
# mais velhos?
# mais novos?
#
# - País (Geography)
# Qual país tem maior churn?
# - Clientes mais velhos apresentam maior taxa de cancelamento, especialmente acima dos 50 anos
# - A Alemanha apresenta a maior taxa de churn entre os países analisados

# %%
df.columns = df.columns.str.strip()
display(df.groupby('Age')['Exited'].mean().sort_values(ascending=False).head(10))
display(df.groupby('Geography')['Exited'].mean().sort_values(ascending=False))
# Out:
# Age
# 56    0.714286
# 52    0.627451
# 54    0.607143
# 55    0.585366
# 51    0.554622
# 53    0.540541
# 50    0.529851
# 60    0.516129
# 49    0.510204
# 57    0.506667
# Name: Exited, dtype: float64
# Geography
# Germany    0.324432
# Spain      0.166734
# France     0.161548
# Name: Exited, dtype: float64

# %%
df.groupby('IsActiveMember')['Exited'].mean()
# Out:
# IsActiveMember
# 0    0.268509
# 1    0.142691
# Name: Exited, dtype: float64

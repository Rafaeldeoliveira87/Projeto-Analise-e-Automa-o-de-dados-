# %%
import smtplib
from email.message import EmailMessage

# %%
email = EmailMessage()
email['Subject'] = 'Relatório de Churn'
email['From'] = 'rdeoliveiraalves966@gmail.com'
email['To'] = 'rafaprovaestudounip@gmail.com'

email.set_content('Segue relatório de análise de churn.')

with open('../Dashboard/churn_por_idade.png', 'rb') as f:
    file_data = f.read()
    email.add_attachment(file_data, maintype='image', subtype='png', filename='grafico.png')

with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
    smtp.login('rdeoliveiraalves966@gmail.com', 'aiay opfo gynr fjrm')
    smtp.send_message(email)

# %%
email = EmailMessage()
email['Subject'] = 'Relatório de Churn'
email['From'] = 'rdeoliveiraalves966@gmail.com'
email['To'] = 'rafaprovaestudounip@gmail.com'

email.set_content('Segue relatório de análise de churn.')

with open('../Dashboard/churn_por_pais.png', 'rb') as f:
    file_data = f.read()
    email.add_attachment(file_data, maintype='image', subtype='png', filename='grafico.png')

with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
    smtp.login('rdeoliveiraalves966@gmail.com', 'aiay opfo gynr fjrm')
    smtp.send_message(email)
